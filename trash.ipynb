# %%
a=10

# %% [markdown]
# # main heading

# %% [markdown]
# ## small heading

# %% [markdown]
# - list
# - list 1
#   - sublist

# %% [markdown]
# ---

# %% [markdown]
# ```python
# print('hello world')
# a=10
# ```
# - sales

# %% [markdown]
# ![](sales.png)
